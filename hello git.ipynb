# %% [markdown]
# <a href="https://colab.research.google.com/github/Dineshbabusekar0105/my-first-repo/blob/main/hello%20git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello git hub")
# Out:
# hello git hub
